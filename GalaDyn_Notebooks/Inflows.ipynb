# %%
import numpy as np
import pandas as pd
import gc
from multiprocessing import Pool
import cmasher as cmr
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=Warning) 
#plt.style.use('dark_background')
path_datos = "/home/bego/GARROTXA_copia/datos_GARROTXA_resim/"
datos_edades = pd.read_csv(path_datos + "edades.csv", sep = ",",index_col = 0)

# %%
def add_satellites(ax):
    transparencia = 0.4
    tamaño = 2   
    #arania
    ax.axvline(x = 6.32, ls='--', c = "mediumblue", linewidth = tamaño, alpha = transparencia)
    ax.axvline(x = 3.90, ls='--', c = "mediumblue", linewidth = tamaño, alpha = transparencia)
    ax.axvline(x = 1.93,ls='--', c = "mediumblue", linewidth = tamaño, alpha = transparencia)
    ax.axvline(x = 0.17, ls='--', c = "mediumblue", linewidth = tamaño, alpha = transparencia)
    #Grillo
    ax.axvline(x = 6.86,ls='--', c = "red", linewidth =tamaño, alpha = transparencia)
    ax.axvline(x = 5.21,ls='--', c = "red", linewidth =tamaño, alpha = transparencia)
    ax.axvline(x = 3.42,ls='--', c = "red", linewidth =tamaño, alpha = transparencia)
    ax.axvline(x = 1.62,ls='--', c = "red", linewidth =tamaño, alpha = transparencia)
    ax.axvline(x = 0.04,ls='--',c = "red", linewidth =tamaño, alpha = transparencia)
    #mosquito
    ax.axvline(x = 7.30,ls='--', c = "magenta", linewidth =tamaño, alpha = transparencia)
    ax.axvline(x = 5.63,ls='--', c = "magenta", linewidth =tamaño, alpha =transparencia)
    ax.axvline(x = 3.99, ls='--',c = "magenta", linewidth =tamaño, alpha = transparencia)
    ax.axvline(x = 2.09,ls='--', c = "magenta", linewidth =tamaño, alpha = transparencia)
    ax.axvline(x = 0.1,ls='--', c = "magenta", linewidth =tamaño, alpha = transparencia)

# %%
inflows = pd.read_csv( f"inflow_mass.csv", sep = ",", index_col = 0)
fig, ax = plt.subplots(figsize = (13,4))
ax.set_title("Inflows")
#
#ax.plot(inflows["Lookback"],inflows["Minf_15"],label = "15 kpc")
ax.plot(inflows["Lookback"],inflows["Minf_20"],label = "20 kpc")
ax.plot(inflows["Lookback"],inflows["Minf_25"],label = "25 kpc")
ax.plot(inflows["Lookback"],inflows["Minf_30"],label = "30 kpc")
ax.plot(inflows["Lookback"],inflows["Minf_35"],label = "35 kpc")
ax.plot(inflows["Lookback"],inflows["Minf_40"],label = "40 kpc")

ax.set_xlim(6.3,0)
ax.set_ylim(1e8,4e8)

ax.grid()
ax.legend(bbox_to_anchor = (1., 1))
#add_satellites(ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 inflows = pd.read_csv( f"inflow_mass.csv", sep = ",", index_col = 0)
#       2 fig, ax = plt.subplots(figsize = (13,4))
#       3 ax.set_title("Inflows")
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'inflow_mass.csv'

# %%
'#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'

# %%
inflows = pd.read_csv( f"/home/bego/GARROTXA/GalaDyn/inflow_mass.csv", sep = ",", index_col = 0)
fig, ax = plt.subplots(figsize = (13,4))
ax.set_title("Inflows")
#
#ax.plot(inflows["Lookback"],inflows["Minf_15"],label = "15 kpc")
ax.plot(inflows["Lookback"],np.log10(inflows["Minf_20"]),label = "15-20 kpc", alpha = 0.2, c = '#1f77b4' )
ax.plot(inflows["Lookback"],np.log10(inflows["Minf_25"]),label = "20-25 kpc", alpha = 0.4, c = '#ff7f0e')
ax.plot(inflows["Lookback"],np.log10(inflows["Minf_30"]),label = "25-30 kpc", alpha = 0.6, c = '#2ca02c')
ax.plot(inflows["Lookback"],np.log10(inflows["Minf_35"]),label = "30-35 kpc", alpha = 0.8, c = '#d62728')
ax.plot(inflows["Lookback"],np.log10(inflows["Minf_40"]),label = "35-40 kpc", alpha = 0.85, c = '#9467bd')



ax.set_xlim(6.3,0)
#ax.set_ylim(0,5e6)

ax.grid()
ax.legend(bbox_to_anchor = (1., 1))
#add_satellites(ax)
plt.show()

# %%
inflows = pd.read_csv( f"/home/bego/GARROTXA/GalaDyn/inflow_mass.csv", sep = ",", index_col = 0)
fig, ax = plt.subplots(figsize = (13,4))
ax.set_title("Inflows")
#
#ax.plot(inflows["Lookback"],inflows["Minf_15"],label = "15 kpc")
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_20"]),label = "15-20 kpc", alpha = 0.2, c = '#1f77b4' )
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_25"]),label = "20-25 kpc", alpha = 0.4, c = '#ff7f0e')
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_30"]),label = "25-30 kpc", alpha = 0.6, c = '#2ca02c')
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_35"]),label = "30-35 kpc", alpha = 0.8, c = '#d62728')
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_40"]),label = "35-40 kpc", alpha = 0.85, c = '#9467bd')

ax.plot(inflows["Lookback"],inflows["Minf_25"],label = "20-25 kpc", alpha = 0.1, c = '#ff7f0e')
ax.plot(inflows["Lookback"],inflows["Minf_30"],label = "25-30 kpc", alpha = 0.3, c = '#2ca02c')
ax.plot(inflows["Lookback"],inflows["Minf_35"],label = "30-35 kpc", alpha = 0.8, c = '#d62728')
ax.plot(inflows["Lookback"],inflows["Minf_40"],label = "35-40 kpc", alpha = 0.85, c = '#9467bd')


ax.set_xlim(6.3,0)
ax.set_ylim(-1e5,2e8)

ax.grid()
ax.legend(bbox_to_anchor = (1., 1))
#add_satellites(ax)
plt.show()

# %%
inflows = pd.read_csv( f"/home/bego/GARROTXA/GalaDyn/inflow_mass.csv", sep = ",", index_col = 0)
fig, ax = plt.subplots(figsize = (13,4))
ax.set_title("Inflows")
#
#ax.plot(inflows["Lookback"],inflows["Minf_15"],label = "15 kpc")
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_20"]),label = "15-20 kpc", alpha = 0.2, c = '#1f77b4' )
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_25"]),label = "20-25 kpc", alpha = 0.4, c = '#ff7f0e')
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_30"]),label = "25-30 kpc", alpha = 0.6, c = '#2ca02c')
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_35"]),label = "30-35 kpc", alpha = 0.8, c = '#d62728')
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_40"]),label = "35-40 kpc", alpha = 0.85, c = '#9467bd')

#ax.plot(inflows["Lookback"],inflows["Minf_25"],label = "20-25 kpc", alpha = 0.1, c = '#ff7f0e')
#ax.plot(inflows["Lookback"],inflows["Minf_30"],label = "25-30 kpc", alpha = 0.3, c = '#2ca02c')
ax.plot(inflows["Lookback"],inflows["Minf_35"],label = "30-35 kpc", alpha = 0.8, c = '#d62728')
ax.plot(inflows["Lookback"],inflows["Minf_40"],label = "35-40 kpc", alpha = 0.85, c = '#9467bd')


ax.set_xlim(6.3,0)
ax.set_ylim(-1e5,1e8)

ax.grid()
ax.legend(bbox_to_anchor = (1., 1))
#add_satellites(ax)
plt.show()

# %%
inflows = pd.read_csv( f"/home/bego/GARROTXA/GalaDyn/inflow_mass.csv", sep = ",", index_col = 0)
fig, ax = plt.subplots(figsize = (13,4))
ax.set_title("Inflows")
#
#ax.plot(inflows["Lookback"],inflows["Minf_15"],label = "15 kpc")
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_20"]),label = "15-20 kpc", alpha = 0.2, c = '#1f77b4' )
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_25"]),label = "20-25 kpc", alpha = 0.4, c = '#ff7f0e')
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_30"]),label = "25-30 kpc", alpha = 0.6, c = '#2ca02c')
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_35"]),label = "30-35 kpc", alpha = 0.8, c = '#d62728')
#ax.plot(inflows["Lookback"],np.log10(inflows["Minf_40"]),label = "35-40 kpc", alpha = 0.85, c = '#9467bd')

ax.plot(inflows["Lookback"],inflows["Minf_25"],label = "20-25 kpc", alpha = 0.4, c = '#ff7f0e')
ax.plot(inflows["Lookback"],inflows["Minf_30"],label = "25-30 kpc", alpha = 0.4, c = '#2ca02c')
#ax.plot(inflows["Lookback"],inflows["Minf_35"],label = "30-35 kpc", alpha = 0.8, c = '#d62728')
#ax.plot(inflows["Lookback"],inflows["Minf_40"],label = "35-40 kpc", alpha = 0.85, c = '#9467bd')


ax.set_xlim(6.3,0)
ax.set_ylim(-1e6,3e8)

ax.grid()
ax.legend(bbox_to_anchor = (1., 1))
#add_satellites(ax)
plt.show()

# %%
seconds_to_Myr = 3.15576e+16

# %%
snapshots_analysis =  [798, 802, 805, 806, 808, 810, 812, 814, 816,
818, 820, 822, 824, 826, 828, 830, 832,834, 836, 839, 840, 842, 844, 846, 848, 850,
853, 855, 856, 858, 860, 862, 864, 867, 870, 872, 875, 877, 879, 881, 883, 884, 888,
890, 892, 894, 898, 900, 902, 904, 907, 908, 910, 912, 915, 916, 918, 921, 922, 924, 927, 929, 
930, 932, 934, 937,
 939, 941,942, 944, 946, 948, 950, 952, 954,956, 
958, 961, 963, 965, 966, 968, 970]

# %%
rango_z=5e-16*seconds_to_Myr 
size = 5
ancho = 40


for name in snapshots_analysis:
    lb = datos_edades.loc[datos_edades['Snapshot'] == name, 'Lookback'].iloc[0]
    az = pd.read_csv( f"/home/bego/GARROTXA/acceleration/mesh_aceleracion_gas_{name}_ytRS_40.csv", sep = ",", index_col = 0)
    az = az[az["R"]>25]
    
    theta = np.linspace(0, 2*np.pi, 100)
    r1 = 25
    x = r1*np.cos(theta)
    y = r1*np.sin(theta)

    fig, ax = plt.subplots(1, 1,figsize = (5,5))
    dm = ax.scatter(az.X,az.Y, marker='s', c=az.az*seconds_to_Myr , 
                cmap= "seismic", s = size, vmin =-rango_z, vmax = rango_z)
    ax.set_title(f"{lb:.2f} Gyr")
    ax.set_box_aspect(1)
    plt.subplots_adjust(left=0 ,bottom= 0.12, right=0.99, top=0.89, wspace=0.2, hspace= 0.09)
    plt.savefig(f"/home/bego/GARROTXA/Disk_maps_gas/az_gas_outer/az_{name}_outer.png", dpi = 100, bbox_inches='tight', facecolor = "white")
    plt.close()
   # plt.show()
